# %% [markdown]
# # $P(< D | E > E_\text{th})$
# The probability that a UHECR is detected from within a distance $D$, given that it is detected with an energy $\hat{E} > E_\text{th}$. Both cases including and excluding the typical detection uncertainties for the UHECR energies.
# <br>
# <br>
# *This code was used to make Figure 3 in Capel & Mortlock (2019).*

# %%
import numpy as np
from scipy import integrate
import h5py

from matplotlib import pyplot as plt
plt.style.use(['minimalist', 'blues'])

# %% [markdown]
# ## Simulating the cosmic ray propagation
#
# In order to show the effect of including the detection uncertainties on the effective GZK horizon, we use the simple model for the propagation of protons as described in the paper. In this way, the results are directly relevant for the model which is later used to fit the data.
#
# To find $P(< D | E > E_\text{th})$ we use Bayes theorem to express this in terms of something that we can calculate through simulations. We have
#
# $$
# P(< D | E > E_\text{th}) = \int_0^{D} dD' \ P(D' | E > E_\text{th}),
# $$
# where
# $$
# P(D | E > E_\text{th}) \propto P(D) \ P(E > E_\text{th} | D).
# $$
#
# We calculate $P(E > E_\text{th} | D)$ and $P(\hat{E} > E_\text{th} | D)$ using simulations. The same <tt>Stan</tt> code as is used in the main model (see `uhecr_E_loss.stan`) is used for consistency and a python script using <tt>MPI</tt> (see `uhecr_E_loss.py`) is used to run many simulations in parallel on HPC services. These scripts can be rerun, but we include the output used in the paper as an hdf5 file (see `simulation_output/`) to show the results here.
# <br>
# <br>
# The script was run with the following parameters:
# * $\alpha = 2$
# * $E_\text{th}^\text{sim} = 20 \ \text{EeV}$
# * $E_\text{th} = 52 \ \text{EeV}$
#
# We simulate down to $E_\text{th}^\text{sim} = 20 \ \text{EeV}$ in order to account for lower energy UHECR events being scattered above the detection threshold by the detection process.

# %%
# Run the simulation script (command line)
# KW: using the cached models, this runs pretty quickly!
! mpirun -n 28 python uhecr_E_loss.py
# Out:
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Using cached StanModel
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.001837 seconds (Sampling)
#                0.001837 seconds (Total)
#
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.001582 seconds (Sampling)
#                0.001582 seconds (Total)
#
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.002197 seconds (Sampling)
#                0.002197 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.001678 seconds (Sampling)
#                0.001678 seconds (Total)
#
# Parr: 0.4175
# Pdet: 0.4175
# time: 0.30643177032470703
# uhecr_E_loss.py:203: RuntimeWarning: Mean of empty slice
#   if np.nanmean(check_arr) == 0.0:
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.504847 seconds (Sampling)
#                0.504847 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.663579 seconds (Sampling)
#                0.663579 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.667952 seconds (Sampling)
#                0.667952 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.1426 seconds (Sampling)
#                1.1426 seconds (Total)
#
# Parr: 0.37749999999999995
# Pdet: 0.3775
# time: 2.3151724338531494
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.641153 seconds (Sampling)
#                0.641153 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.762244 seconds (Sampling)
#                0.762244 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.29183 seconds (Sampling)
#                1.29183 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.38886 seconds (Sampling)
#                1.38886 seconds (Total)
#
# Parr: 0.3925
# Pdet: 0.3675
# time: 2.630720615386963
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.697981 seconds (Sampling)
#                0.697981 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.797327 seconds (Sampling)
#                0.797327 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.26037 seconds (Sampling)
#                1.26037 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.31945 seconds (Sampling)
#                1.31945 seconds (Total)
#
# Parr: 0.275
# Pdet: 0.2525
# time: 2.5163447856903076
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.767372 seconds (Sampling)
#                0.767372 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.896301 seconds (Sampling)
#                0.896301 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.933095 seconds (Sampling)
#                0.933095 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.48056 seconds (Sampling)
#                1.48056 seconds (Total)
#
# Parr: 0.1625
# Pdet: 0.17
# time: 3.0015883445739746
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.8606 seconds (Sampling)
#                0.8606 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.03073 seconds (Sampling)
#                1.03073 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.24687 seconds (Sampling)
#                1.24687 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.82463 seconds (Sampling)
#                1.82463 seconds (Total)
#
# Parr: 0.0
# Pdet: 0.08499999999999999
# time: 3.62428617477417
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.813101 seconds (Sampling)
#                0.813101 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.0366 seconds (Sampling)
#                1.0366 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.22714 seconds (Sampling)
#                1.22714 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.75292 seconds (Sampling)
#                1.75292 seconds (Total)
#
# Parr: 0.0
# Pdet: 0.01
# time: 3.50296950340271
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.935902 seconds (Sampling)
#                0.935902 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.16083 seconds (Sampling)
#                1.16083 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.30858 seconds (Sampling)
#                1.30858 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                2.01015 seconds (Sampling)
#                2.01015 seconds (Total)
#
# Parr: 0.0
# Pdet: 0.0
# time: 4.048076868057251
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.94106 seconds (Sampling)
#                0.94106 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.18397 seconds (Sampling)
#                1.18397 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.3696 seconds (Sampling)
#                1.3696 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.92479 seconds (Sampling)
#                1.92479 seconds (Total)
#
# Parr: 0.0
# Pdet: 0.0
# time: 3.8925023078918457
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Using cached StanModel
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
# Iteration: 1 / 1 [100%]  (Sampling)
#
#  Elapsed Time: 0 seconds (Warm-up)
#                0.926446 seconds (Sampling)
#                0.926446 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.31174 seconds (Sampling)
#                1.31174 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.3834 seconds (Sampling)
#                1.3834 seconds (Total)
#
#
#  Elapsed Time: 0 seconds (Warm-up)
#                1.66398 seconds (Sampling)
#                1.66398 seconds (Total)
#
# Parr: 0.0
# Pdet: 0.0
# time: 3.8071963787078857

# %% [markdown]
# ## Read simulation ouput

# %%
# Simulation inputs and outputs are stored in the same file
with h5py.File('output/paper_uhecr_E_loss_output.h5', 'r') as f:

    # inputs (to check)
    Eth = f['Eth'][()]
    Eth_sim = f['Eth_sim'][()]
    alpha = f['alpha'][()]
    Ds = f['Ds']
    Ncr = f['Ncr'][()]
    Ntrials = f['Ntrials'][()]
    f_E = f['f_E'][()]
    
    # Results
    Parr = f['Parr'][()] # arrival energy > Eth
    Pdet = f['Pdet'][()] # detected energy > Eth
    D = f['D'][()]

# %%
# Plot to show
fig, ax = plt.subplots()
fig.set_size_inches((6, 5))
ax.plot(D, Parr, label = '$E$')
ax.plot(D, Pdet, label = '$\hat{E}$')
ax.set_ylim(0)
ax.set_xlabel('D / Mpc')
ax.set_ylabel('$P(E > E_\mathrm{th} | D)$')
ax.legend();

# %% [markdown]
# ## Find $P(< D | E > E_\text{th})$

# %%
P_E_D = Parr 
P_Edet_D = Pdet 

# Bayes rule (P(D) ~ D^2)
P_D_E = D**2 * P_E_D
P_D_Edet = D**2 * P_Edet_D

# Normalisation
P_D_E = P_D_E / integrate.simps(P_D_E, D)
P_D_Edet = P_D_Edet / integrate.simps(P_D_Edet, D)

# Cumulative distribution
c_P_D_E = integrate.cumtrapz(P_D_E, D, initial = 0)
c_P_D_Edet = integrate.cumtrapz(P_D_Edet, D, initial = 0)

# %% [markdown]
# ## Figure 3

# %%
from fancy.plotting.colours import darkgrey

fig, ax = plt.subplots()
fig.set_size_inches(6, 5)

ax.plot(D, c_P_D_E, label = '$E$')
ax.plot(D, c_P_D_Edet, label = '$\hat{E}$', linestyle = '--')
ax.axhline(0.9, color = darkgrey, linestyle = ':')

ax.set_ylim(0, 1.01)
ax.set_xlabel('D / Mpc')
ax.set_ylabel('$P(< D | \hat{E} > E_\mathrm{th})$')
ax.text(250, 0.5, '$E_\mathrm{th} = 52$ EeV \n $\\alpha = 2$', fontsize = 16)
ax.legend();
